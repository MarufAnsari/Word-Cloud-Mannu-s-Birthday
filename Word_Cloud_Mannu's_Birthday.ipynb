# %% [markdown]
# <a href="https://colab.research.google.com/github/MarufAnsari/Word-Cloud-Mannu-s-Birthday/blob/main/Word_Cloud_Mannu's_Birthday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Word Cloud : Mannu's Birthday**
# “Word clouds (also known as text clouds or tag clouds) work in a simple way: the more a specific word appears in a source of textual data (such as a speech, blog post, or database), the bigger and bolder it appears in the word cloud.”

# %% [markdown]
# First of all, let’s import all the primary libraries first.

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
from PIL import Image # converting images into arrays
import matplotlib.pyplot as plt # for visualizing the data
from google.colab import files # for uploading files
from io import BytesIO

# %% [markdown]
# Upload all the images and relevant text file.

# %%
# uploadng image files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-863ae101-972b-49ef-8ad7-da68ecf7301b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-863ae101-972b-49ef-8ad7-da68ecf7301b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving House-Stark-Game-Of-Thrones-1-Vinyl-Decal-Sticker__00348.1506202647.jpg to House-Stark-Game-Of-Thrones-1-Vinyl-Decal-Sticker__00348.1506202647 (3).jpg
# Saving txm.txt to txm (3).txt

# %% [markdown]
# Python package already exists in Python for generating word clouds.

# %%
# install wordcloud
# !pip install wordcloud

# %% [markdown]
# Now let’s import the package and it's set of stopwords.

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# Word clouds are commonly used to perform high-level analysis and visualization of text data. Let’s try to analyze a short self synthesid text file describing Mannu's life.
# Let’s go ahead and open the uploaded text file.

# %%
mannu_novel = open('txm.txt', 'r').read()
print ('File downloaded and saved!')
# Out:
# File downloaded and saved!

# %% [markdown]
# Next, let’s use the stopwords that we imported from ‘word_cloud’. We use the function ‘set’ to remove any redundant stopwords and Create a word cloud object and generate a word cloud.

# %%
stopwords = set(STOPWORDS)
# instantiate a word cloud object
mannu_wc = WordCloud(
    background_color='black',
    contour_width=2,
    max_font_size=40,
    min_font_size=2,
    contour_color='white',
    stopwords=stopwords
)
# generate the word cloud
mannu_wc.generate(mannu_novel)

# %% [markdown]
# Awesome! Now that the word cloud is created, let’s visualize it.

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig.set_figwidth(15) # set width
fig.set_figheight(20) # set height

# display the word cloud
plt.imshow(mannu_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Much better! However, said isn’t really an informative word. So let’s add it to our stopwords and re-generate the cloud.

# %%
stopwords.add('Rathi') # add the words said to stopwords
# re-generate the word cloud
mannu_wc.generate(mannu_novel)
# display the cloud
fig = plt.figure()
fig.set_figwidth(15) # set width
fig.set_figheight(20) # set height
plt.imshow(mannu_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Excellent! This looks really interesting! Another cool thing you can implement with the word_cloud package is superimposing the words onto a mask of any shape. Let's use a mask of mannu. I have already created the mask , so let's go ahead and use the above uploaded mask.

# %% [markdown]
# Let’s take a look at how the mask looks like.

# %%
mannu_im = Image.open(BytesIO(uploaded['House-Stark-Game-Of-Thrones-1-Vinyl-Decal-Sticker__00348.1506202647.jpg']))
mannu_mask = np.array(mannu_im)
fig = plt.figure()
fig.set_figwidth(8) # set width
fig.set_figheight(12) # set height
plt.imshow(mannu_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Shaping the word cloud according to the mask is straightforward using `word_cloud` package.

# %%
import random
# custom red-brick color
def red_color_func(word=None, font_size=None, position=None, orientation=None, font_path=None, random_state=None):
    return "hsl(10, 100%%, %d%%)" % random.randint(40, 100)

# %% [markdown]
# (Note : you can try run this part many times for better wordcloud)

# %%
# instantiate a word cloud object
mannu_wc = WordCloud(background_color='black', mask=mannu_mask, stopwords=stopwords, color_func=red_color_func,
                     max_words=3000, max_font_size=256, random_state=42, width=mannu_mask.shape[1], height=mannu_mask.shape[0])
# generate the word cloud
mannu_wc.generate(mannu_novel)
# display the word cloud
fig = plt.figure()
fig.set_figwidth(15) # set width
fig.set_figheight(20) # set height
plt.imshow(mannu_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# .............................................**Winter is coming**..............................................

# %% [markdown]
# **Happy Birthday Mannu**
#
# **\- Maruf**
